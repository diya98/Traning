# %%
import numpy as np
import pandas as pd

# %%
csvfile=pd.read_csv(r'C:\Users\user\Desktop\1.csv')

# %%
csvfile
# Out:
#     Series reference          Period  \
# 0            2019.09  PPIQ.SQN800000
# 1            2019.12  PPIQ.SQN800000
# 2            2019.09  PPIQ.SQN800001
# 3            2019.12  PPIQ.SQN800001
# 4            2019.09  PPIQ.SQN900000
# ..               ...             ...
# 62           2019.12  PPIQ.SQUCC1300
# 63           2019.09  PPIQ.SQUCC1310
# 64           2019.12  PPIQ.SQUCC1310
# 65           2019.12  PPIQ.SQUCC3200
# 66           2019.12  PPIQ.SQUCC3210
#
#                                           Description  Revised  \
# 0   All industries excl admin health educati, Inpu...     1167
# 1   All industries excl admin health educati, Inpu...     1170
# 2   All industries ex admin health edu OOD, Inputs...     1167
# 3   All industries ex admin health edu OOD, Inputs...     1170
# 4            All industries, Inputs Indexes (Level 0)     1166
# ..                                                ...      ...
# 62  Dairy Product Manufacturing, Outputs Indexes (...     1220
# ...

# %%
csvfile=pd.read_csv(r'C:\Users\user\Desktop\1.csv',header=None)

# %%
csvfile
# Out:
#                    0               1  \
# 0   Series reference          Period
# 1            2019.09  PPIQ.SQN800000
# 2            2019.12  PPIQ.SQN800000
# 3            2019.09  PPIQ.SQN800001
# 4            2019.12  PPIQ.SQN800001
# ..               ...             ...
# 63           2019.12  PPIQ.SQUCC1300
# 64           2019.09  PPIQ.SQUCC1310
# 65           2019.12  PPIQ.SQUCC1310
# 66           2019.12  PPIQ.SQUCC3200
# 67           2019.12  PPIQ.SQUCC3210
#
#                                                     2        3  \
# 0                                         Description  Revised
# 1   All industries excl admin health educati, Inpu...     1167
# 2   All industries excl admin health educati, Inpu...     1170
# 3   All industries ex admin health edu OOD, Inputs...     1167
# 4   All industries ex admin health edu OOD, Inputs...     1170
# ..                                                ...      ...
# 63  Dairy Product Manufacturing, Outputs Indexes (...     1220
# ...

# %%
csvfile=pd.read_csv(r'C:\Users\user\Desktop\1.csv',names=['wwhite','red','yellow','orange','pink'])

# %%
csvfile
# Out:
#               wwhite             red  \
# 0   Series reference          Period
# 1            2019.09  PPIQ.SQN800000
# 2            2019.12  PPIQ.SQN800000
# 3            2019.09  PPIQ.SQN800001
# 4            2019.12  PPIQ.SQN800001
# ..               ...             ...
# 63           2019.12  PPIQ.SQUCC1300
# 64           2019.09  PPIQ.SQUCC1310
# 65           2019.12  PPIQ.SQUCC1310
# 66           2019.12  PPIQ.SQUCC3200
# 67           2019.12  PPIQ.SQUCC3210
#
#                                                yellow   orange  \
# 0                                         Description  Revised
# 1   All industries excl admin health educati, Inpu...     1167
# 2   All industries excl admin health educati, Inpu...     1170
# 3   All industries ex admin health edu OOD, Inputs...     1167
# 4   All industries ex admin health edu OOD, Inputs...     1170
# ..                                                ...      ...
# 63  Dairy Product Manufacturing, Outputs Indexes (...     1220
# ...

# %%
csvfile=pd.read_csv(r'C:\Users\user\Desktop\1.csv',index_col=['Period','Revised'])

# %%
csvfile
# Out:
#                         Series reference  \
# Period         Revised
# PPIQ.SQN800000 1167              2019.09
#                1170              2019.12
# PPIQ.SQN800001 1167              2019.09
#                1170              2019.12
# PPIQ.SQN900000 1166              2019.09
# ...                                  ...
# PPIQ.SQUCC1300 1220              2019.12
# PPIQ.SQUCC1310 1243              2019.09
#                1220              2019.12
# PPIQ.SQUCC3200 1015              2019.12
# PPIQ.SQUCC3210 1015              2019.12
#
#                                                               Description  \
# Period         Revised
# PPIQ.SQN800000 1167     All industries excl admin health educati, Inpu...
#                1170     All industries excl admin health educati, Inpu...
# PPIQ.SQN800001 1167     All industries ex admin health edu OOD, Inputs...
#                1170     All industries ex admin health edu OOD, Inputs...
# ...
