# %%
im=plt.imread("1.jpg")
im.shape
im
# Out:
# array([[[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
#         ...,
#         [255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255]],
#
#        [[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
#         ...,
#         [255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255]],
#
#        [[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
#         ...,
#         [255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255]],
#
#        ...,
#
#        [[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
#         ...,
#         [255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255]],
#
#        [[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
#         ...,
#         [255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255]],
#
#        [[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
# ...

# %%
imc=im[:,:,:3] # removing alpha channel gives opacity value
imc.shape
# Out:
# (692, 1104, 3)

# %%
a=np.random.random((2,3,4))
a
# Out:
# array([[[0.3777719 , 0.94127403, 0.70787764, 0.38982519],
#         [0.30738887, 0.69259968, 0.39862349, 0.357996  ],
#         [0.68637747, 0.79003286, 0.17900555, 0.00628863]],
#
#        [[0.92752321, 0.63799267, 0.0844911 , 0.31798979],
#         [0.89826198, 0.47531218, 0.03538229, 0.17274726],
#         [0.30020862, 0.28678381, 0.40691675, 0.59106324]]])

# %%
def plti(im,h=8,**kwargs):
    """
    Helper fnction to plot an image
    """
    y=im.shape[0]
    x=im.shape[1]
    w=(y/x)*h
    plt.figure(figsize=(w,h))
    plt.imshow(im,interpolation='none',**kwargs)
    plt.axis('off')
    
plti(im)

# %%
import numpy as np
import matplotlib.pylab as plt
# %matplotlib inline
array=np.zeros([100,200,4],dtype=np.uint8)
array[:,:100]=[255,128,0,255]#orannge left side
array[:,100:]=[0,0,255,255]#Blue right side
for x in range(200):
    for y in range(100):
        array[y,x,3]=x
        
plti(array)

# %%
#Croping image
im2=im[100:550,100:600,:3]
plti(im2)

# %%
#individual color challange
lena=plt.imread("Pic1.png")
lena.shape
# Out:
# (512, 512, 3)

# %%
lena_R=lena.copy()
lena_R[:,:,(1,2)]=0
lena_G=lena.copy()
lena_G[:,:,(0,2)]=0
lena_B=lena.copy()
lena_B[:,:,(0,1)]=0
lena_RGB=np.concatenate((lena_R,lena_G,lena_B),axis=1)
plti(lena_RGB,30)

# %%
#grayscaleimage
def to_grayscale(im,weights=np.c_[0.2989,0.5870,0.1140]):
    tile=np.tile(weights,reps=(im.shape[0],im.shape[1],1))
    return np.sum(tile*im,,axis=2)
# Out:
#   File "<ipython-input-37-27c30968bc40>", line 4
#     return np.sum(tile*im,,axis=2)
#                           ^
# SyntaxError: invalid syntax
